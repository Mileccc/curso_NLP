# %% [markdown]
# # Word2Vec
#
# Word2Vec es un modelo que se utiliza para aprender representaciones vectoriales de palabras. Estas representaciones pueden capturar muchas propiedades linguisticas de las palabras, como su significado semántico, gramatical y hasta contextual.

# %% [markdown]
# ### 1. Extraer la Data

# %% [markdown]
# Detectar codificación

# %%
# !pip install chardet

# %%
import chardet

# %%
with open("./CaballeriaRoja_Babel.txt", "rb") as file:
    raw_data = file.read()
    result = chardet.detect(raw_data)
    encoding = result['encoding']
    print(f"Detected encoding: {encoding}")
# Out:
# Detected encoding: Windows-1252

# %%
# !pip install pypdf2 -q

# %%
import string
from gensim.models import Word2Vec
import PyPDF2

# %%
with open("./CaballeriaRoja_Babel.txt", "r", encoding="Windows-1252") as file:
    documento = file.read()

# %%
documento
# Out:
# 'CABALLERÍA ROJA\n\nIsaac Babel\n(1894-c.1941 )\n\nLA HIJA\n\nEl comandante de la sexta división comunicó que al amanecer el nuevo día había que ocupar Novogrado-Volynsk. El estado mayor abandonó Krapivno, y nuestro convoy, con gran estruendo, quedó como retaguardia a lo largo de la carretera, de aquella indestructible carretera que va de Brest a Varsovia, mandada construir un día por Nicolás I con huesos de campesinos.\nFlorecen en torno, los campos de adormidera púrpura; el viento sur juguetea en los centenos amarillos; el tierno trigo sarraceno se recorta en el horizonte como el muro de un convento lejano. La apacible Volinia se extiende a nuestro lado; ante nosotros retrocede y se hunde en los bosques de abedules una niebla nacarina que escala luego las cuestas floridas, prendiéndose con sus tenues brazos a las ramas de lúpulo. El sol, de color naranja, rueda por el horizonte como una cabeza cortada; en las desgarraduras de las nubes se estremece una luz débil; sobre nuestras cabezas tremolan los estandartes del ocaso; el olor de la sangre vertida la víspera y el de los caballos muertos se filtra en el frescor vesperal. El Sbrutch se oscurece, murmura y enlaza los espumosos nudos de sus remolinos de agua. Como los puentes están rotos, vadeamos el río. Sobre las ondas reposa la luna mayestática. Los caballos se hunden en el agua hasta el lomo, y la corriente culebrea murmuradora entre los centenares de patas de los caballos. Un soldado que amenaza ahogarse reniega brutalmente de la madre de Dios. Las manchas negras\n\nde los carros cubren el río, lleno de ruido, de silbidos y de cánticos, que resuenan sobre la centelleante sierpe de luz lunar y los fulgentes remansos de las ondas.\nMuy entrada la noche, llegamos a Novogrado. En el alojamiento que me designan, encuentro una mujer embarazada, dos judíos rojizos de rostro enjuto y un tercero, dormido ya, con la cabeza tapada y apretado contra la pared. Los armarios están violentados; se ven por el suelo pingajos de pieles femeninas, excrementos humanos y trozos del vaso sagrado que los judíos usan una vez al año, en la pascua.\nLimpie usted esto —digo a la mujer—. ¡En qué porquería viven! Los dos judíos se levantan de sus asientos. Como japoneses en el circo, silenciosos, simiescos, calzados de fieltro, recogen del suelo a saltitos los pedazos. Van y vienen con los cuellos congestionados. Extienden para mí un lecho de plumas roto, y me echo contra la pared, junto al tercero, el judío que duerme. Sobre mi cama cae en el acto una miseria horrenda.\nTodo ha muerto en el silencio. Sólo la luna, cogiéndose con azuladas manos su cabeza redonda, luminosa, indiferente, pasa vagando por la ventana.\nEstiro los pies hinchados, me tiendo en el lecho desgarrado y quedo dormido. Sueño con el comandante de la sexta división, que galopa en su pesado caballo tras del comandante de brigada y le dispara dos balas en los ojos.\n\nLas balas atraviesan la cabeza del comandante de brigada, y los dos ojos caen al suelo. —¿Por qué has ordenado retirarse a la brigada? —grita el comandante de la sexta división al herido Savitski. Y entonces despierto, porque la mujer encinta me tienta la cara con los dedos.\n—Panie —me dice—, está usted gritando en sueños y dando vueltas. Voy a hacerle la cama en otro rincón, porque tropieza usted con mi padre.\nLevanta del suelo sus piernas flacas y el vientre redondo, y destapa al hombre que dormía. A mi lado veo a un anciano muerto, boca abajo, con la garganta abierta, el rostro partido y sangre azul en la barba como un pedazo de plomo.\n—Panie —dice la judía, mientras sacude el cobertor de plumas—, los polacos le han martirizado, y él suplicaba: "Matadme en el corral para que mi hija no me vea morir." Pero hicieron lo que quisieron. En este cuarto murió pensando en mí... Y ahora quisiera yo saber —dijo la mujer alzando horriblemente la voz de pronto—, quisiera saber dónde encontrará usted otro padre como el mío en la tierra...\n\nLA IGLESIA DE NOVOGRADO\n\n\n  Ayer ...

# %%
len(documento)
# Out:
# 204238

# %% [markdown]
# ### 2. Preprocesamiento de datos

# %% [markdown]
# El objetivo del preprocesamiento es convertir el documento en una lista de frases, y cada frase en una lista de palabras, eliminando signos de puntuación y convirtiendo todo a minúsculas.

# %%
# Dividir el documento en frases usando el punto como separador
oraciones = documento.split(".")
len(oraciones)
# Out:
# 2616

# %%
oraciones[1]
# Out:
# '1941 )\n\nLA HIJA\n\nEl comandante de la sexta división comunicó que al amanecer el nuevo día había que ocupar Novogrado-Volynsk'

# %%
oraciones_limpias = []
for oracion in oraciones:
    # Eliminar puntuación y dividir por espacios
    tokens = oracion.translate(str.maketrans('', '', string.punctuation)).split()
    
    # Convertir a minúsculas y eliminar números
    tokens = [word.lower() for word in tokens if word.isalpha()]
    
    # Añadir solo si hay tokens
    if tokens:
        oraciones_limpias.append(tokens)

# %%
oraciones_limpias[1]
# Out:
# ['la',
#  'hija',
#  'el',
#  'comandante',
#  'de',
#  'la',
#  'sexta',
#  'división',
#  'comunicó',
#  'que',
#  'al',
#  'amanecer',
#  'el',
#  'nuevo',
#  'día',
#  'había',
#  'que',
#  'ocupar',
#  'novogradovolynsk']

# %% [markdown]
# ### 3. Entrenamiento del modelo Word2Vec

# %%
# Entrenar el modelo Word2Vec
model = Word2Vec(sentences=oraciones_limpias, vector_size=500, window=5, min_count=1, workers=8)

# %%
vector = model.wv['historia']

# %%
palabras_cercanas = model.wv.most_similar('historia', topn=10)
palabras_cercanas
# Out:
# [('en', 0.9983624219894409),
#  ('que', 0.9983614087104797),
#  ('un', 0.9983577728271484),
#  ('es', 0.9983543753623962),
#  ('le', 0.9983530044555664),
#  ('su', 0.9983522295951843),
#  ('de', 0.9983511567115784),
#  ('nuestro', 0.9983500838279724),
#  ('los', 0.9983497262001038),
#  ('como', 0.9983471035957336)]

# %%
model.save("caballeria_roja.model")

# %%
modelo_cargado = Word2Vec.load("caballeria_roja.model")

# %%
palabras_cercanas = modelo_cargado.wv.most_similar("caballero", topn=10)
palabras_cercanas
# Out:
# [('algo', 0.9611254334449768),
#  ('unos', 0.9607442617416382),
#  ('tiene', 0.9606738686561584),
#  ('hombres', 0.9606360197067261),
#  ('tengo', 0.960549533367157),
#  ('podía', 0.9605357646942139),
#  ('ciudad', 0.9605245590209961),
#  ('todos', 0.9604822993278503),
#  ('poco', 0.9604784846305847),
#  ('ni', 0.960443377494812)]

# %% [markdown]
# Guardar solo los embeddings

# %%
model.wv.save_word2vec_format("caballero_emb.txt", binary=False)
model.wv.save_word2vec_format("caballero_emb.bin", binary=True)

# %%
from gensim.models import KeyedVectors

# %%
embeddings_cargados = KeyedVectors.load_word2vec_format("caballero_emb.txt", binary=False)
# O si fue guardado en formato binario:
# embeddings_cargados = KeyedVectors.load_word2vec_format("caballero_emb.bin", binary=True)
embeddings_cargados

# %%
def analogias(v1,v2,v3):
    similitud = embeddings_cargados.most_similar(positive=[v1,v3], negative=[v2])
    print(f"{v1} es a {v2} como {similitud[0][0]} es a {v3}")

# %%
analogias("caballero","hombre","mujer")
# Out:
# caballero es a hombre como algo es a mujer

# %% [markdown]
# ### Prueba modelo 100 años de soleadad

# %%
def extraer_texto_desde_pdf(ruta_archivo):
    with open(ruta_archivo, "rb") as archivo:
        lector = PyPDF2.PdfReader(archivo)
        texto = ""
        for pagina in range(len(lector.pages)):
            texto += lector.pages[pagina].extract_text()
    return texto

# %%
documento = extraer_texto_desde_pdf("./cien-anos-de-soledad-gabriel-garcia-marquez.pdf")
documento
# Out:
# "CIEN AÑOS DE \nSOLEDAD\nGabriel García Márquez\nInfoLibros.org\nS I N O P S I S   D E   C I E N   A Ñ O S   D E   S O L E D A D \n \nCien años de soledad es sin lugar a dudas la novela má s \ncélebre de la literatura hispanoamericana del siglo XX. Algunos \ncríticos han enmarcado a Cien años de soledad en lo que se \nconoce como el realismo mágico o “lo real maravilloso”, una \ncorriente literaria de los países latinoamericanos donde la \nrealidad co nvive  con lo sobrenatural, mientras los personajes \nde las obras experimentan el fenómeno sin ningún asombro.  \n \nCien años de soledad narra la historia de los Buendía a lo largo \nde 100 años, una familia que habitaba el pueblo de Macondo. \nTanto los nombres, c omo los miedos, obsesiones y fracasos \nsuelen repetirse una y otra vez dentro de la trama, dejando al \nlector con la sensación de que los personajes están atrapados \npor la fuerza de la herencia familiar.   \n \nCien años de soledad por Gabriel García Márquez  en \nInfoLibros.org  S i  d e s e a s  l e e r  e s t a  o b r a  e n  o t r o s  i d i o m a s ,  s ó l o  t i e n e s  q u e\nh a c e r  c l i c  s o b r e  l o s  e n l a c e s  c o r r e s p o n d i e n t e s :\n● I n g l é s  I n f o B o o k s . o r g : O n e  H u n d r e d  Y e a r s  o f  S o l i t u d e a u t h o r  G a b r i e l\nG a r c í a  M á r q u e z\n● P o r t u g u é s  I n f o L i v r o s . o r g : C e m  A n o s  d e  S o l i d ã o  o  a u t o r G a b r i e l\nG a r c í a  M á r q u e z\n● F r a n c é s  I n f o L i v r e s . o r g : C e n t  a n s  d e  s o l i t u d e  a u t e u r G a b r i e l  G a r c í a\nM á r q u e z\nS i  q u i e r e s  l e e r  y  d e s c a r g a r  m á s  l i b r o s  d e G a b r i e l G a r c í a\nM á r q u e z e n  f o r m a t o  P D F  t e  i n v i t a m o s  a  q u e  v i s i t e s e s t á\np á g i n a :\n● L i b r o s  d e  G a b r i e l  G a r c í a  M á r q u e z  e n  f o r m a t o  P D F e n\nI n f o L i b r o s . o r g\nS i  q u i e r e s  a c c e d e r  a  n u e s t r a  b i b l i o t e c a  d i g i t a l  c o n  m á s  d e\n3 . 5 0 0  l i b r o s  p a r a  l e e r  y  d e s c a r g a r  g r a t i s ,  t e  i n v i t a m o s  a\nq u e  v i s i t e s  e s t á  p á g i n a :\n● + 3 . 5 0 0  l i b r o s  g r a t i s  e n  f o r m a t o  P D F e n  I n f o L i b r o s . o r gC A P Í T U L O  I  \n \nMuchos años después, frente al pelotón de fusilamiento, el coronel \nAureliano Buendía había de recordar aquella tarde remota en que \nsu padre lo llevó a conocer el hielo. Macondo era entonces una \naldea de veinte casas de barro y cañabrava construidas a la or illa \nde un río de aguas diáfanas que se precipitaban por un lecho de \npiedras pulidas, blancas y enormes como huevos prehistóricos. El  \nmundo  era  tan  reciente,  que  muchas  cosas  carecían  de  \nnombre,  y  para mencionarlas había que señalarías con el d edo. \nTodos los años, por el mes de marzo, una familia de gitanos \ndesarrapados plantaba su carpa cerca de la aldea, y con un \ngrande alboroto de pitos y timbales daban a conocer los nuevos \ninventos. Primero llevaron el imán. Un gitano corpulento, de barba \nmontaraz y manos de gorrión, que se presentó con el nombre de \nMelquiades, hizo una truculenta demostración pública de lo que él \nmismo llamaba la octava maravilla de los sabios alquimistas de \nMacedonia. Fue de casa en casa arrastrando dos lingotes \nmetálicos, y todo el mundo se espantó al ver que los calderos, las \npailas, las tenazas y los anafes se caían de su sitio, y las maderas \ncrujían por la desesperación de los clavos y los tornillos tratando \nde desenclavarse, y aun los objetos perdidos desde hacía mucho \ntiempo aparecían por donde más se les había buscado, y se \n4arrastraban en desbandada turbulenta detrás de los fierros \nmágicos de Melquíades.  \n«Las cosas, tienen vida propia -pregonaba el gitano con áspero \nacento -, todo es cuestión de despertarles el ánima.» José Arcadio \nBuendía, cuya desaforada imaginaci ...

# %%
len(documento)
# Out:
# 832032

# %%
# Dividir el documento en frases usando la coma como separador
oraciones = documento.split(",")
len(oraciones)
# Out:
# 8862

# %%
oraciones[0]
# Out:
# 'CIEN AÑOS DE \nSOLEDAD\nGabriel García Márquez\nInfoLibros.org\nS I N O P S I S   D E   C I E N   A Ñ O S   D E   S O L E D A D \n \nCien años de soledad es sin lugar a dudas la novela má s \ncélebre de la literatura hispanoamericana del siglo XX. Algunos \ncríticos han enmarcado a Cien años de soledad en lo que se \nconoce como el realismo mágico o “lo real maravilloso”'

# %%
oraciones_limpias = []
for oracion in oraciones:
    # Eliminar puntuación y dividir por espacios
    tokens = oracion.translate(str.maketrans('', '', string.punctuation)).split()
    
    # Convertir a minúsculas y eliminar números
    tokens = [word.lower() for word in tokens if word.isalpha()]
    
    # Añadir solo si hay tokens
    if tokens:
        oraciones_limpias.append(tokens)

# %%
oraciones_limpias[1]
# Out:
# ['una',
#  'corriente',
#  'literaria',
#  'de',
#  'los',
#  'países',
#  'latinoamericanos',
#  'donde',
#  'la',
#  'realidad',
#  'co',
#  'nvive',
#  'con',
#  'lo',
#  'sobrenatural']

# %%
model = Word2Vec(sentences=oraciones_limpias, vector_size=500, window=5, min_count=1, workers=8)

# %%
palabras_cercanas = model.wv.most_similar('buendía', topn=10)
palabras_cercanas
# Out:
# [('segundo', 0.997196614742279),
#  ('coronel', 0.9967167377471924),
#  ('josé', 0.9946346879005432),
#  ('promovió', 0.9855259656906128),
#  ('raquel', 0.9844239354133606),
#  ('confió', 0.9836245179176331),
#  ('aureliano', 0.983380138874054),
#  ('fusilarán', 0.9823739528656006),
#  ('buendia', 0.982210636138916),
#  ('seminario', 0.9812296032905579)]

# %%
model.wv.save_word2vec_format("100as_emb.txt", binary=False)

# %%
embeddings_cargados = KeyedVectors.load_word2vec_format("100as_emb.txt", binary=False)
def analogias(v1,v2,v3):
    similitud = embeddings_cargados.most_similar(positive=[v1,v3], negative=[v2])
    print(f"{v1} es a {v2} como {similitud[0][0]} es a {v3}")

# %%
analogias("caballero","hombre","mujer")
# Out:
# caballero es a hombre como llegó es a mujer

# %% [markdown]
# ### Prueba modelo con muchos pdfs

# %%
# !pip install tqdm -q

# %%
import os
import PyPDF2
from tqdm import tqdm

# %%
def extraer_texto_desde_pdf(ruta_archivo):
    with open(ruta_archivo, "rb") as archivo:
        lector = PyPDF2.PdfReader(archivo)
        texto = ""
        for pagina in range(len(lector.pages)):
            texto += lector.pages[pagina].extract_text()
    return texto

# %%
ruta_carpeta = "./varios _pdf/"
todos_los_textos = []

for archivo in tqdm(os.listdir(ruta_carpeta)):
    if archivo.endswith(".pdf"):
        ruta_completa = os.path.join(ruta_carpeta, archivo)
        try:
            documento = extraer_texto_desde_pdf(ruta_completa)
            todos_los_textos.append(documento)
        except Exception as e:
            print(f"Error al procesar {archivo}: {e}")
# Out:
#   2%|▏         | 3/134 [00:05<04:14,  1.94s/it]incorrect startxref pointer(3)
#  25%|██▌       | 34/134 [03:53<03:20,  2.00s/it]
# Error al procesar 01. Introduccion a la Biología Evoluiva autor Marco A. Méndez y José Navarro B..pdf: PyCryptodome is required for AES algorithm
# Error al procesar 01. Introducción a la automatización Autor Teacherke.pdf: PyCryptodome is required for AES algorithm
# 100%|██████████| 134/134 [15:44<00:00,  7.05s/it]

# %%
todos_los_textos[0]
# Out:
# 'Alfonso Nieves Gómez©UNIVERSIDAD LIBRE, SEDE CARTAGENA \nAPUNTES DE DErEcho r om ANo \nAutor: Alfonso Nieves Gómez\nISBN: 978-958-8621-49-4  \nPrimera Edición, 2010 América del Sur \nTeléfonos: 661147- 6561379\nEditorial Universidad Libre, Sede Cartagena\ncomiTé EDiT oriAl\nRafael Ballestas Morales\nCarlos Gustavo Méndez Rodríguez\nArmando noriega Ruiz\nMaría Cristina Bustillo\nZilath Romero González\nDiagramación e Impresión: \nAlPhA  EDiT orES\nCartagena de Indias, Colombia Año 2014\nSe permite la reproducción total y parcial por cualquier \nmedio siempre y cuando se citen debidamente la \nfuente, los autores y las instituciones. La Universidad \nLibre, Sede Cartagena no se hace responsable por \nlos contenidos, posibles errores u omisiones. Los \ncontenidos son responsabilidad exclusiva de sus \nautores.UNiVErSiDAD liBrE \nDirEc TiVoS NA cioNAlES 2014 \nPresidente Nacional\nVíctor Hernando Alvarado Ardila\nrector Nacional\nNicolás Enrique Zuleta Hincapié\ncensor Nacional\nBenjamín Ochoa Moreno\nDecano Facultad de Derecho\nJesús Hernando Álvarez Mora\nDecano Facultad de c ontaduría\nClara Inés Camacho\nDirEc TiVoS SEccioNAlES 2014 \nPresidente Delegado rector\nRafael Ballestas Morales\nVicerrector\nCarlos Gustavo Méndez Rodríguez\nSecretario General\nLuis María Rangel Sepúlveda\nDirector Administrativo y Financiero\nLucy Castilla Bravo\nDecano de Extensión de Derecho\nNarciso Castro Yanes\nDecana de la Facultad de c iencias\nEconómicas, Administrativas y c ontables\nMaría Cristina Bustillo Castillejo\nDirectora c onsultorio Jurídico y \ncentro de c onciliación\nTulia del Carmen Barrozo Osorio \ncoordinadora de Postgrados \nBeatriz Tovar Carrasquilla \nDirectora c entro de i nvestigaciones\nZilath Romero González\nLa publicación de los artículos está sujeta a los criterios del \nComité Editorial y la evaluación de los pares científicos. Las \nopiniones expresadas por los autores son independientes \ny no comprometen a la Universidad Libre, Sede Cartagena. \nSe respeta la libertad de expresión.\nUniversidad Libre\nPie de la Popa Calle. Real # 20-177 Cartagena de Indias. \nColombia América del Sur Teléfonos: 6661147- 6561379contenido\nPrÓloGo ............................................................................................................................................................................................ 9\niNTroDUcciÓN ............................................................................................................................................................................ 11\n1. coNcEPT o DE oBliGA ciÓN\n1.1 DIFERENCIA ENTRE LOS EFECTOS QUE PRODUCEN LOS DERECHOS REALES Y LOS DERECHOS \nPERSONALES ...................................................................................................................................................................... 15\n1.2 DEFINICIÓN DE OBLIGACIÓN. SEGÚN JUSTINIANO .............................................................................................. 15\n1.3 ELEMENTOS DE ESTA DEFINICIÓN .............................................................................................................................. 15\n1.4 ¿CÓMO NACIAN LAS OBLIGACIONES ENTRE LOS ROMANOS? ......................................................................... 16\n1.5 CLASIFICACIÓN DE LAS OBLIGACIONES ................................................................................................................... 16\n1.6 CONCEPTO DE CONVENCIÓN ....................................................................................................................................... 16\n1.7 ELEMENTOS DE LA CONVENCIÓN Y DEL CONTRATO ........................................................................................... 17\n1.8 DEFINICION DE CAPACIDAD ......................................................................................................................................... 17\n1.9 LOS INCAPACES ............................................... ...

# %%
oraciones_totales = []
tamaño = 0

for documento in todos_los_textos:
    tamaño = tamaño + len(documento)
    oraciones = documento.split(".")
    oraciones_totales.extend(oraciones)

# %%
print(f"Número de carácteres totales: {tamaño}")
# Out:
# Número de carácteres totales: 76976392

# %%
print(len(oraciones_totales))
# Out:
# 1112072

# %%
oraciones_limpias = []
for oracion in oraciones_totales:
    # Eliminar puntuación y dividir por espacios
    tokens = oracion.translate(str.maketrans("","",string.punctuation)).split()
    
    # Convertir a minúsculas 
    tokens = [word.lower() for word in tokens if word.isalpha()]
    
    # Añadir solo si hay tokens
    if tokens:
        oraciones_limpias.append(tokens)

# %%
oraciones_limpias[0]
# Out:
# ['alfonso',
#  'nieves',
#  'libre',
#  'sede',
#  'cartagena',
#  'apuntes',
#  'de',
#  'derecho',
#  'r',
#  'om',
#  'ano',
#  'autor',
#  'alfonso',
#  'nieves',
#  'gómez',
#  'isbn',
#  'primera',
#  'edición',
#  'américa',
#  'del',
#  'sur',
#  'teléfonos',
#  'editorial',
#  'universidad',
#  'libre',
#  'sede',
#  'cartagena',
#  'comité',
#  'edit',
#  'orial',
#  'rafael',
#  'ballestas',
#  'morales',
#  'carlos',
#  'gustavo',
#  'méndez',
#  'rodríguez',
#  'armando',
#  'noriega',
#  'ruiz',
#  'maría',
#  'cristina',
#  'bustillo',
#  'zilath',
#  'romero',
#  'gonzález',
#  'diagramación',
#  'e',
#  'impresión',
#  'alpha',
#  'edit',
#  'ores',
#  'cartagena',
#  'de',
#  'indias',
#  'colombia',
#  'año',
#  'se',
#  'permite',
#  'la',
#  'reproducción',
#  'total',
#  'y',
#  'parcial',
#  'por',
#  'cualquier',
#  'medio',
#  'siempre',
#  'y',
#  'cuando',
#  'se',
#  'citen',
#  'debidamente',
#  'la',
#  'fuente',
#  'los',
#  'autores',
#  'y',
#  'las',
#  'instituciones']

# %%
model = Word2Vec(sentences=oraciones_limpias, vector_size=500, window=5, min_count=1, workers=12)

# %%
palabras_cercanas = model.wv.most_similar("noche", topn=10)
palabras_cercanas
# Out:
# [('mañana', 0.9067478775978088),
#  ('calle', 0.7260098457336426),
#  ('nave', 0.7242533564567566),
#  ('vela', 0.7215090394020081),
#  ('tarde', 0.719170093536377),
#  ('batalla', 0.7172651290893555),
#  ('pelea', 0.7017942070960999),
#  ('madrugada', 0.6982910633087158),
#  ('oscuridad', 0.6973426342010498),
#  ('cama', 0.6966083645820618)]

# %%
palabras_cercanas = model.wv.most_similar("amor", topn=10)
palabras_cercanas
# Out:
# [('odio', 0.8147440552711487),
#  ('placer', 0.7937672734260559),
#  ('dolor', 0.7887848615646362),
#  ('afecto', 0.7607267498970032),
#  ('hombre', 0.7562950253486633),
#  ('sentimiento', 0.750781238079071),
#  ('espíritu', 0.7465107440948486),
#  ('corazón', 0.7341040968894958),
#  ('desprecio', 0.7281666994094849),
#  ('respeto', 0.7279638648033142)]

# %%
model.save("mod_13textos.model")

# %%
model.wv.save_word2vec_format("emb_13textos.txt", binary=False)

# %%
from gensim.models import KeyedVectors

embeddings_cargados = KeyedVectors.load_word2vec_format("emb_13textos.txt", binary=False)

# %%
def analogias(v1,v2,v3):
    similitud = embeddings_cargados.most_similar(positive=[v1,v3], negative=[v2])
    print(f"{v1} es a {v2} como {similitud[0][0]} es a {v3}")

# %%
analogias("cielo","aire","tierra")
# Out:
# cielo es a aire como luna es a tierra

# %%
analogias("universo","estrellas","libro")
# Out:
# universo es a estrellas como discurso es a libro

# %%
analogias("oso","mamífero","salmón")
# Out:
# oso es a mamífero como braud es a salmón
